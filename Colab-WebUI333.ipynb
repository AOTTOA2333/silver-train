# %% [markdown]
# <a href="https://colab.research.google.com/github/AOTTOA2333/silver-train/blob/main/Colab-WebUI333.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !apt-get install -y p7zip-full
!7z x /content/drive/MyDrive/GPT-SoVITS-v2pro-20250604.7z -o/content/
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 8152988462 bytes (7776 MiB)
#
# Extracting archive: /content/drive/MyDrive/GPT-SoVITS-v2pro-20250604.7z
# --
# Path = /content/drive/MyDrive/GPT-SoVITS-v2pro-20250604.7z
# Type = 7z
# Physical Size = 8152988462
# Headers Size = 657383
# Method = Delta LZMA2:26 LZMA:20 BCJ2
# Solid = +
# Blocks = 8
#
# Everything is Ok
#
# Folders: 7325
# Files: 50357
# Size:       14126101810
# Compressed: 8152988462

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:02:13
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5712, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 5712 (delta 39), reused 10 (delta 10), pack-reused 5651 (from 3)
# Receiving objects: 100% (5712/5712), 13.69 MiB | 4.16 MiB/s, done.
# Resolving deltas: 100% (3374/3374), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.9.9   |       h06a4308_0         127 KB
# ...

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !unzip /content/drive/MyDrive/Tobiichi.zip -d /content/input
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Archive:  /content/drive/MyDrive/Tobiichi.zip
#   inflating: /content/input/2024「慢著――！」.ogg
#   inflating: /content/input/2026「當然是為了制止『我』啊！不要許那種願望！」.ogg
#   inflating: /content/input/2028「還問為什麼……」.ogg
#   inflating: /content/input/2031「唔……！」.ogg
#   inflating: /content/input/2032「重點不在這裡！不要隨意將五河同學當寵物對待啊！」.ogg
#   inflating: /content/input/2033「而且這個叫蓮的女孩是什麼人？她說可以實現願望，究竟有何企圖？」.ogg
#   inflating: /content/input/2034「就算這只是夢，也太不現實了，應該慎重考慮。」.ogg
#   inflating: /content/input/2035「夢嘛，妳知道的，與深層意識存在關聯，如果許下奇怪的願望，說不定會對現實中的自己產生影響喔。」.ogg
#   inflating: /content/input/2036「所以，如果要許願，還是許下讓五河同學身體健康這種正常的願望比較好。」.ogg
#   inflating: /content/input/2037「還有……希望可以增加一點和五河同學在一起的時間……」.ogg
#   inflating: /content/input/2039「達成共識了嗎！？」.ogg
#   inflating: /content/input/2041「聽到我剛才說的話了嗎！？」.ogg
#   inflating: /content/input/2043「這成何體統！？豈不是被當成狗了嗎！？」.ogg
#   inflating: /content/input/2045「我、我覺得五河同學說不出那種話……」.ogg
# ...

# %%
# !unzip /content/drive/MyDrive/工具包.zip -d /content/
# !pip install uv
# !uv pip install -r /content/工具包/requirements.txt
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Archive:  /content/drive/MyDrive/工具包.zip
#    creating: /content/工具包/
#   inflating: /content/工具包/accelerate_audio_fast.py
#    creating: /content/工具包/audio/
#    creating: /content/工具包/audio/accelerate/
#    creating: /content/工具包/audio/blankRemove/
#    creating: /content/工具包/audio/finished/
#    creating: /content/工具包/audio/louder/
#    creating: /content/工具包/audio/output/
#    creating: /content/工具包/audio/phone/
#    creating: /content/工具包/audio/temp/
#   inflating: /content/工具包/audios_accelerate.py
#   inflating: /content/工具包/audios_blank_remove.py
#   inflating: /content/工具包/audios_post_process.py
#    creating: /content/工具包/check/
#   inflating: /content/工具包/check/check_audios_accelerated.py
#   inflating: /content/工具包/check/check_audios_integrity.py
#   inflating: /content/工具包/check/check_audios_left.py
#   inflating: /content/工具包/gsv.py
# ...

# %%
# !cp -r /content/工具包/* /content/
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !unzip /content/drive/MyDrive/Tobiichi.zip -d /content/input

# %%
# !uv pip install -r /content/GPT-SoVITS-v2pro-20250604/requirements.txt
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Using Python 3.12.7 environment at: /usr/local
# Resolved 208 packages in 5.06s
# Prepared 118 packages in 2m 29s
# Uninstalled 9 packages in 252ms
# Installed 118 packages in 994ms
#  + absl-py==2.3.1
#  + accelerate==1.10.1
#  + addict==2.4.0
#  + aliyun-python-sdk-core==2.16.0
#  + aliyun-python-sdk-kms==2.16.5
#  + antlr4-python3-runtime==4.9.3
#  + audioread==3.0.1
#  + av==15.1.0
#  + budoux==0.7.0
#  + cn2an==0.5.23
#  + coloredlogs==15.0.1
#  + colorlog==6.9.0
#  + crcmod==1.7
#  + ctranslate2==4.6.0
#  + datasets==4.1.1
#  + distance==0.1.3
#  + dnspython==2.8.0
#  + editdistance==0.8.1
#  + einops==0.8.1
#  + einx==0.3.0
#  + email-validator==2.3.0
#  + fast-langdetect==1.0.0
#  + fastapi-cli==0.0.13
#  + fastapi-cloud-cli==0.2.1
#  + fasttext-predict==0.9.2.4
#  + ffmpeg-python==0.2.0
#  + flatbuffers==25.9.23
#  + funasr==1.0.27
#  + future==1.0.0
#  + g2p-en==2.1.0
# ...

# %%
# !cd /content/GPT-SoVITS-v2pro-20250604 && source activate GPTSoVITS && export is_share=True && python webui.py & python /content/ui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Traceback (most recent call last):
#   File "/content/ui.py", line 536, in <module>
#     with gr.Row(equal_height=True, min_height=200):
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/site-packages/gradio/component_meta.py", line 167, in wrapper
#     return fn(self, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
# TypeError: Row.__init__() got an unexpected keyword argument 'min_height'
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://a454b4ab75fdecf5c3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
