# %% [markdown]
# <a href="https://colab.research.google.com/github/AOTTOA2333/silver-train/blob/main/ChatGPT-SoVITS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:58
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5712, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 5712 (delta 39), reused 10 (delta 10), pack-reused 5651 (from 3)
# Receiving objects: 100% (5712/5712), 13.68 MiB | 17.83 MiB/s, done.
# Resolving deltas: 100% (3377/3377), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.9.9   |       h06a4308_0         127 KB
# ...

# %%
# !pip install uv
# !uv pip install -r /content/GPT-SoVITS/requirements.txt
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 100.9 MB/s eta 0:00:00
# ...
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Using Python 3.12.7 environment at: /usr/local
# Resolved 209 packages in 6.15s
# Prepared 133 packages in 2m 25s
# Uninstalled 6 packages in 124ms
# Installed 133 packages in 940ms
#  + absl-py==2.3.1
#  + accelerate==1.10.1
#  + addict==2.4.0
#  + aiofiles==23.2.1
#  + aliyun-python-sdk-core==2.16.0
#  + aliyun-python-sdk-kms==2.16.5
#  + antlr4-python3-runtime==4.9.3
#  + audioread==3.0.1
#  + av==16.0.1
#  + budoux==0.7.0
#  + cn2an==0.5.23
#  + coloredlogs==15.0.1
#  + colorlog==6.10.1
#  + crcmod==1.7
#  + ctranslate2==4.6.0
#  + datasets==4.2.0
#  + distance==0.1.3
#  + dnspython==2.8.0
#  + editdistance==0.8.1
#  + einops==0.8.1
#  + einx==0.3.0
#  + email-validator==2.3.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/工具包.zip -d /content/
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Archive:  /content/drive/MyDrive/工具包.zip
#   inflating: /content/accelerate_audio_fast.py
#    creating: /content/audio/
#    creating: /content/audio/accelerate/
#    creating: /content/audio/blankRemove/
#    creating: /content/audio/finished/
#    creating: /content/audio/louder/
#    creating: /content/audio/output/
#    creating: /content/audio/phone/
#    creating: /content/audio/temp/
#   inflating: /content/audios_accelerate.py
#   inflating: /content/audios_blank_remove.py
#   inflating: /content/audios_post_process.py
#    creating: /content/check/
#   inflating: /content/check/check_audios_accelerated.py
#   inflating: /content/check/check_audios_integrity.py
#   inflating: /content/check/check_audios_left.py
#   inflating: /content/gsv.py
#   inflating: /content/instructions.md
#    creating: /content/jsons/
#   inflating: /content/jsons/05_military.json
# ...

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !uv pip install -r /content/requirements.txt
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Using Python 3.12.7 environment at: /usr/local
# Resolved 54 packages in 199ms
# Prepared 6 packages in 1.61s
# Uninstalled 5 packages in 48ms
# Installed 6 packages in 93ms
#  - gradio==4.44.1
#  + gradio==5.18.0
#  - gradio-client==1.3.0
#  + gradio-client==1.7.2
#  - numpy==1.26.4 (from file:///croot/numpy_and_numpy_base_1708638617955/work/dist/numpy-1.26.4-cp312-cp312-linux_x86_64.whl)
#  + numpy==1.26.2
#  + safehttpx==0.1.6
#  - send2trash==1.8.2 (from file:///work/perseverance-python-buildout/croot/send2trash_1701732325573/work)
#  + send2trash==1.8.3
#  - tqdm==4.66.5 (from file:///croot/tqdm_1724853939799/work)
#  + tqdm==4.67.1

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py & python /content/ui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# * Running on local URL:  http://localhost:6657
# * Running on public URL: https://13672f1fbf80567feb.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://f69509ffee33f3a871.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# 正在清空文件夹:audio/output: 0it [00:00, ?it/s]
# Loaded as API: http://localhost:9874/ ✔
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/site-packages/gradio/queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
# ...
