# %% [markdown]
# <a href="https://colab.research.google.com/github/AOTTOA2333/silver-train/blob/main/new-RVC-MAKER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <h1 align="center"><b>Ultimate RVC Maker 🎵</b></h1>
# <div align="center">
#
# A high-quality voice conversion tool focused on experimentation and performance, built upon [Vietnamese-RVC](https://github.com/PhamHuynhAnh16/Vietnamese-RVC), a fork of the original Retrieval-based Voice Conversion (RVC) project.
#
# </div>
#
# ---
#
# ## <h2 align="center">Overview</h2>
#
# This notebook provides a streamlined environment to set up and run the Ultimate RVC Maker, including installation, web interface, Google Drive integration, and model uploading to Hugging Face. Follow the cells below to get started.
#
# **Resources:**
# - [Support Discord](https://discord.gg/aihub)
# - [GitHub Repository](https://github.com/unchCrew/RVC-MAKER.git)
# - [Terms of Use](https://github.com/unchCrew/RVC-MAKER/blob/main/TERMS_OF_USE.md)
#
# **Created by:** [TheNeoDev](https://github.com/TheNeodev)
#
# ---
#
# ## <h2 align="center">Acknowledgments</h2>
#
# Special thanks to:
# - **Original RVC Team**: For developing the core Retrieval-based Voice Conversion framework.
# - **Vietnamese-RVC**: For providing an up-to-date fork used as the base for this project.
#
# ## <h2 align="center">Disclaimer</h2>
#
# By using Ultimate RVC Maker, you agree to:
# - Comply with ethical and legal standards.
# - Respect intellectual property and privacy rights.
# - Avoid harmful or prohibited uses.
# - Accept full responsibility for any outcomes.
#
# Ultimate RVC Maker disclaims liability and reserves the right to amend these terms. See the [Terms of Use](https://github.com/unchCrew/RVC-MAKER/blob/main/TERMS_OF_USE.md) for details.

# %%
#@title **Install Ultimate RVC Maker**

import os
from IPython.display import clear_output

print("👩🏻‍💻 Starting installation...")

# Suppress TensorFlow logging
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Clone repository
if not os.path.exists('/content/program'):
    # !git clone https://github.com/sekkit/RVC-MAKER.git /content/program
else:
    print("Repository already cloned, skipping...")

# Install dependencies
# !pip install -r /content/program/requirements.txt  > /dev/null 2>&1
# !pip install pyngrok  > /dev/null 2>&1
# !pip install torch --index-url https://download.pytorch.org/whl/cu128  > /dev/null 2>&1

# Verify installation
try:
    import torch
    print(f"PyTorch version: {torch.__version__}")
except ImportError:
    print("⚠️ Failed to import PyTorch. Installation may have issues.")

clear_output()
print("✅ Installation completed successfully! (~2 minutes)")
#@markdown **Note:** Installation typically takes about 2 minutes. If issues arise, check the output for errors.
# Out:
# ✅ Installation completed successfully! (~2 minutes)

# %%
# !pip install gradio==5.37
# Out:
# Collecting gradio==5.37
#   Downloading gradio-5.37.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (4.10.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.116.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.3.1)
# Collecting gradio-client==1.10.4 (from gradio==5.37)
#   Downloading gradio_client-1.10.4-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.34.4)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (3.11.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (2.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.12.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.47.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.16.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.37) (0.35.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.10.4->gradio==5.37) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.10.4->gradio==5.37) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio==5.37) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio==5.37) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==5.37) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==5.37) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio==5.37) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio==5.37) (3.19.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio==5.37) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio==5.37) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.28.1->gradio==5.37) (1.1.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.37) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.37) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.37) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio==5.37) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio==5.37) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.0->gradio==5.37) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.37) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.37) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.37) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio==5.37) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.37) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.37) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.28.1->gradio==5.37) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.28.1->gradio==5.37) (2.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==5.37) (0.1.2)
# Downloading gradio-5.37.0-py3-none-any.whl (59.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 MB 15.0 MB/s eta 0:00:00
# Downloading gradio_client-1.10.4-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.9/323.9 kB 28.5 MB/s eta 0:00:00
# Installing collected packages: gradio-client, gradio
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.10.1
#     Uninstalling gradio_client-1.10.1:
#       Successfully uninstalled gradio_client-1.10.1
#   Attempting uninstall: gradio
#     Found existing installation: gradio 5.29.1
#     Uninstalling gradio-5.29.1:
#       Successfully uninstalled gradio-5.29.1
# Successfully installed gradio-5.37.0 gradio-client-1.10.4

# %%
#@title **Run Web Interface**
#@markdown Launch the Ultimate RVC Maker web interface using your preferred sharing method.

import os
import threading
import time
import urllib.request
import ipywidgets as widgets
from IPython.display import display
from pyngrok import ngrok

# %cd /content/program

#@markdown ### Options
#@markdown - **Enable TensorBoard**: Monitor training progress (logs saved in `./assets/logs`).
tensorboard = False #@param {type:"boolean"}

#@markdown - **Sharing Method**: Choose how to access the web interface.
method = "gradio" #@param ["gradio", "localtunnel", "ngrok"]

#@markdown - **Ngrok Token**: Required for ngrok sharing. Get it from [ngrok dashboard](https://dashboard.ngrok.com/get-started/your-authtoken).
ngrok_token = "" #@param {type:"string"}

def start_gradio():
    print("Starting Gradio interface...")
    # !python main/app/app.py --share

def start_localtunnel():
    print("Starting localtunnel...")
    # !npm install -g localtunnel &>/dev/null
    with open('url.txt', 'w') as file:
        file.write('')
    get_ipython().system_raw('lt --port 7860 >> url.txt 2>&1 &')
    time.sleep(3)
    try:
        endpoint_ip = urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip()
        with open('url.txt', 'r') as file:
            tunnel_url = file.read().replace("your url is: ", "").strip()
        print(f"Share Link: \033[93m{tunnel_url}\033[0m")
        display(widgets.Text(value=endpoint_ip, description='Password IP:', disabled=True))
        # !python main/app/app.py
    except Exception as e:
        print(f"Error starting localtunnel: {e}")

def start_ngrok():
    if not ngrok_token:
        print("⚠️ Ngrok token is required. Please provide a valid token.")
        return
    try:
        ngrok.set_auth_token(ngrok_token)
        ngrok.kill()
        tunnel = ngrok.connect(7860)
        print(f"Ngrok URL: \033[93m{tunnel.public_url}\033[0m")
        # !python main/app/app.py --listen
    except Exception as e:
        print(f"Error starting ngrok: {e}")

def start_app():
    try:
        if method == "gradio":
            start_gradio()
        elif method == "localtunnel":
            start_localtunnel()
        elif method == "ngrok":
            start_ngrok()
    except Exception as e:
        print(f"Failed to start application: {e}")

# Start TensorBoard if enabled
if tensorboard:
    # %load_ext tensorboard
    # %tensorboard --logdir ./assets/logs --port=6870

# Start application in a separate thread
thread_app = threading.Thread(target=start_app)
thread_app.start()

# Keep the cell running
while True:
    time.sleep(5)

#@markdown **Note:** Use the interface for full functionality. If using TensorBoard, check for overtraining in the logs.
# Out:
# /content/program
# Starting Gradio interface...
#
# 2025-08-28 14:29:16.544 | INFO | utils | cuda:0
#
# 2025-08-28 14:29:18.107 | INFO | app | Starting interface...
#
# 2025-08-28 14:29:18.107 | INFO | app | Display language set to en-US.
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://0a613a86707ccf4046.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
#
# 2025-08-28 14:30:07.784 | INFO | utils | Starting music separation...
#
# 2025-08-28 14:30:09.823 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 14:30:09.823 | INFO | separator | Initializing with output path: audios/ShibayanRecords,Rainych - disco light feat. Rainych, output format: wav
#
# 2025-08-28 14:30:09.823 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 14:30:09.825 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 14:30:09.825 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 14:30:09.825 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 14:30:09.826 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 14:30:09.826 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 14:30:09.826 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 14:30:09.826 | INFO | separator | Loading model htdemucs.yaml...
#
# 2025-08-28 14:30:10.507 | INFO | demucs_separator | Demucs Separator initialization completed
#
# 2025-08-28 14:30:10.507 | INFO | separator | Model loading duration: 00:00:00
#
# 2025-08-28 14:30:10.507 | INFO | separator | Starting separation process for audio file path: audios/ShibayanRecords,Rainych - disco light feat. Rainych.flac
# 100% 4/4 [00:50<00:00, 12.70s/it]
# 100% 4/4 [00:47<00:00, 11.83s/it]
#
# 2025-08-28 14:31:55.673 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:31:55.673 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:31:55.986 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:31:55.986 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:31:56.350 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:31:56.357 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:31:56.734 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:31:56.735 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:31:57.289 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 14:31:57.290 | INFO | separator | Separation duration: 00:01:46
#
# 2025-08-28 14:31:58.274 | INFO | separator_music | Music separation successful!
#
# 2025-08-28 14:31:58.275 | INFO | separator_music | Music separation completed in 108.45 seconds
#
# 2025-08-28 14:31:59.096 | INFO | utils | Completed!
#
# 2025-08-28 14:33:12.189 | INFO | utils | Starting music separation...
#
# 2025-08-28 14:33:14.005 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 14:33:14.005 | INFO | separator | Initializing with output path: audios/ShibayanRecords,Rainych - disco light feat. Rainych, output format: wav
#
# 2025-08-28 14:33:14.006 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 14:33:14.007 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 14:33:14.007 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 14:33:14.007 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 14:33:14.008 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 14:33:14.008 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 14:33:14.008 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 14:33:14.008 | INFO | separator | Loading model UVR-MDX-NET-Inst_HQ_5.onnx...
# UVR-MDX-NET-Inst_HQ_5.onnx: 100% 59074342/59074342 [00:00<00:00, 61848628.50byte/s]
#
# 2025-08-28 14:33:18.516 | INFO | separator | Model loading duration: 00:00:04
#
# 2025-08-28 14:33:18.517 | INFO | separator | Starting separation process for audio file path: audios/ShibayanRecords,Rainych - disco light feat. Rainych.flac
# 100%|████████████████████████████████████████████████████████████████| 79/79 [00:23<00:00,  3.34f/s]
# 100%|████████████████████████████████████████████████████████████████| 61/61 [00:06<00:00,  9.99f/s]
#
# 2025-08-28 14:33:50.614 | INFO | mdx_separator | Saving secondary stem Vocals to ShibayanRecords,Rainych - disco light feat. Rainych_(Vocals)_UVR-MDX-NET-Inst_HQ_5.wav...
#
# 2025-08-28 14:33:50.616 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:33:50.616 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:33:50.889 | INFO | mdx_separator | Saving secondary stem Instrumental to ShibayanRecords,Rainych - disco light feat. Rainych_(Instrumental)_UVR-MDX-NET-Inst_HQ_5.wav...
#
# 2025-08-28 14:33:50.890 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:33:50.890 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:33:51.337 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 14:33:51.337 | INFO | separator | Separation duration: 00:00:32
#
# 2025-08-28 14:33:51.357 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 14:33:51.357 | INFO | separator_music | Music separation completed in 37.37 seconds
#
# 2025-08-28 14:33:52.217 | INFO | utils | Completed!
#
# 2025-08-28 14:34:19.824 | INFO | utils | Starting music separation...
#
# 2025-08-28 14:34:21.611 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 14:34:21.611 | INFO | separator | Initializing with output path: audios/ShibayanRecords,Rainych - disco light feat. Rainych, output format: wav
#
# 2025-08-28 14:34:21.611 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 14:34:21.613 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 14:34:21.613 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 14:34:21.613 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 14:34:21.614 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 14:34:21.614 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 14:34:21.614 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 14:34:21.614 | INFO | separator | Loading model UVR-MDX-NET-Inst_HQ_5.onnx...
#
# 2025-08-28 14:34:23.851 | INFO | separator | Model loading duration: 00:00:02
#
# 2025-08-28 14:34:23.851 | INFO | separator | Starting separation process for audio file path: audios/ShibayanRecords,Rainych - disco light feat. Rainych.flac
# 100%|████████████████████████████████████████████████████████████████| 79/79 [00:23<00:00,  3.37f/s]
# 100%|████████████████████████████████████████████████████████████████| 61/61 [00:07<00:00,  8.49f/s]
#
# 2025-08-28 14:34:56.526 | INFO | mdx_separator | Saving secondary stem Vocals to ShibayanRecords,Rainych - disco light feat. Rainych_(Vocals)_UVR-MDX-NET-Inst_HQ_5.wav...
#
# 2025-08-28 14:34:56.527 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:34:56.527 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:34:56.794 | INFO | mdx_separator | Saving secondary stem Instrumental to ShibayanRecords,Rainych - disco light feat. Rainych_(Instrumental)_UVR-MDX-NET-Inst_HQ_5.wav...
#
# 2025-08-28 14:34:56.795 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:34:56.795 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:34:57.233 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 14:34:57.234 | INFO | separator | Separation duration: 00:00:33
#
# 2025-08-28 14:34:57.254 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 14:34:57.254 | INFO | separator_music | Music separation completed in 35.66 seconds
#
# 2025-08-28 14:34:58.054 | INFO | utils | Completed!
#
# 2025-08-28 14:36:01.604 | INFO | utils | Starting music separation...
#
# 2025-08-28 14:36:03.584 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 14:36:03.585 | INFO | separator | Initializing with output path: audios/ShibayanRecords,Rainych - disco light feat. Rainych, output format: wav
#
# 2025-08-28 14:36:03.585 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 14:36:03.586 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 14:36:03.586 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 14:36:03.586 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 14:36:03.588 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 14:36:03.588 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 14:36:03.588 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 14:36:03.588 | INFO | separator | Loading model UVR-MDX-NET-Inst_Main.onnx...
# UVR-MDX-NET-Inst_Main.onnx: 100% 52786726/52786726 [00:01<00:00, 46468215.75byte/s]
#
# 2025-08-28 14:36:07.228 | INFO | separator | Model loading duration: 00:00:03
#
# 2025-08-28 14:36:07.229 | INFO | separator | Starting separation process for audio file path: audios/ShibayanRecords,Rainych - disco light feat. Rainych.flac
# 100%|████████████████████████████████████████████████████████████████| 79/79 [00:19<00:00,  4.00f/s]
# 100%|████████████████████████████████████████████████████████████████| 61/61 [00:06<00:00,  9.58f/s]
#
# 2025-08-28 14:36:35.480 | INFO | mdx_separator | Saving secondary stem Vocals to ShibayanRecords,Rainych - disco light feat. Rainych_(Vocals)_UVR-MDX-NET-Inst_Main.wav...
#
# 2025-08-28 14:36:35.482 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:36:35.482 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:36:35.764 | INFO | mdx_separator | Saving secondary stem Instrumental to ShibayanRecords,Rainych - disco light feat. Rainych_(Instrumental)_UVR-MDX-NET-Inst_Main.wav...
#
# 2025-08-28 14:36:35.765 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:36:35.765 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:36:36.194 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 14:36:36.195 | INFO | separator | Separation duration: 00:00:28
#
# 2025-08-28 14:36:36.214 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 14:36:36.215 | INFO | separator_music | Music separation completed in 32.63 seconds
#
# 2025-08-28 14:36:37.017 | INFO | utils | Completed!
#
# 2025-08-28 14:38:26.815 | INFO | utils | Starting music separation...
#
# 2025-08-28 14:38:28.622 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 14:38:28.623 | INFO | separator | Initializing with output path: audios/ShibayanRecords,Rainych - disco light feat. Rainych, output format: wav
#
# 2025-08-28 14:38:28.623 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 14:38:28.624 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 14:38:28.624 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 14:38:28.624 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 14:38:28.625 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 14:38:28.625 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 14:38:28.625 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 14:38:28.625 | INFO | separator | Loading model UVR_MDXNET_3_9662.onnx...
# UVR_MDXNET_3_9662.onnx: 100% 29704436/29704436 [00:00<00:00, 40123276.74byte/s]
#
# 2025-08-28 14:38:32.102 | INFO | separator | Model loading duration: 00:00:03
#
# 2025-08-28 14:38:32.102 | INFO | separator | Starting separation process for audio file path: audios/ShibayanRecords,Rainych - disco light feat. Rainych.flac
# 100%|████████████████████████████████████████████████████████████████| 20/20 [00:15<00:00,  1.31f/s]
# 100%|████████████████████████████████████████████████████████████████| 16/16 [00:06<00:00,  2.30f/s]
#
# 2025-08-28 14:38:56.456 | INFO | mdx_separator | Saving secondary stem Instrumental to ShibayanRecords,Rainych - disco light feat. Rainych_(Instrumental)_UVR_MDXNET_3_9662.wav...
#
# 2025-08-28 14:38:56.458 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:38:56.458 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:38:56.730 | INFO | mdx_separator | Saving secondary stem Vocals to ShibayanRecords,Rainych - disco light feat. Rainych_(Vocals)_UVR_MDXNET_3_9662.wav...
#
# 2025-08-28 14:38:56.731 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:38:56.731 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:38:57.166 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 14:38:57.167 | INFO | separator | Separation duration: 00:00:25
#
# 2025-08-28 14:38:57.167 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 14:38:57.167 | INFO | separator_music | Music separation completed in 28.56 seconds
#
# 2025-08-28 14:38:57.981 | INFO | utils | Completed!
#
# 2025-08-28 14:39:53.768 | INFO | utils | Starting music separation...
#
# 2025-08-28 14:39:55.555 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 14:39:55.555 | INFO | separator | Initializing with output path: audios/ShibayanRecords,Rainych - disco light feat. Rainych, output format: wav
#
# 2025-08-28 14:39:55.555 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 14:39:55.556 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 14:39:55.556 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 14:39:55.556 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 14:39:55.557 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 14:39:55.557 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 14:39:55.558 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 14:39:55.558 | INFO | separator | Loading model UVR_MDXNET_3_9662.onnx...
#
# 2025-08-28 14:39:58.598 | INFO | separator | Model loading duration: 00:00:03
#
# 2025-08-28 14:39:58.598 | INFO | separator | Starting separation process for audio file path: audios/ShibayanRecords,Rainych - disco light feat. Rainych.flac
# 100%|████████████████████████████████████████████████████████████████| 20/20 [00:14<00:00,  1.37f/s]
# 100%|████████████████████████████████████████████████████████████████| 16/16 [00:07<00:00,  2.03f/s]
#
# 2025-08-28 14:40:23.358 | INFO | mdx_separator | Saving secondary stem Instrumental to ShibayanRecords,Rainych - disco light feat. Rainych_(Instrumental)_UVR_MDXNET_3_9662.wav...
#
# 2025-08-28 14:40:23.360 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:40:23.360 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:40:23.668 | INFO | mdx_separator | Saving secondary stem Vocals to ShibayanRecords,Rainych - disco light feat. Rainych_(Vocals)_UVR_MDXNET_3_9662.wav...
#
# 2025-08-28 14:40:23.671 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:40:23.671 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:40:24.119 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 14:40:24.120 | INFO | separator | Separation duration: 00:00:25
#
# 2025-08-28 14:40:24.120 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 14:40:24.121 | INFO | separator_music | Processing original vocal reverb removal...
#
# 2025-08-28 14:40:24.121 | INFO | separator | Initializing with output path: audios/ShibayanRecords,Rainych - disco light feat. Rainych, output format: wav
#
# 2025-08-28 14:40:24.121 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 14:40:24.121 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 14:40:24.121 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 14:40:24.121 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 14:40:24.122 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 14:40:24.122 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 14:40:24.122 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 14:40:24.122 | INFO | separator | Loading model Reverb_HQ_By_FoxJoy.onnx...
# Reverb_HQ_By_FoxJoy.onnx: 100% 66780123/66780123 [00:00<00:00, 341395385.45byte/s]
#
# 2025-08-28 14:40:25.310 | INFO | separator | Model loading duration: 00:00:01
#
# 2025-08-28 14:40:25.310 | INFO | separator | Starting separation process for audio file path: audios/ShibayanRecords,Rainych - disco light feat. Rainych/Original_Vocals.wav
# 100%|████████████████████████████████████████████████████████████████| 20/20 [00:25<00:00,  1.28s/f]
# 100%|████████████████████████████████████████████████████████████████| 16/16 [00:08<00:00,  1.94f/s]
#
# 2025-08-28 14:41:00.217 | INFO | mdx_separator | Saving secondary stem No Reverb to Original_Vocals_(No Reverb)_Reverb_HQ_By_FoxJoy.wav...
#
# 2025-08-28 14:41:00.218 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:41:00.218 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:41:00.490 | INFO | mdx_separator | Saving secondary stem Reverb to Original_Vocals_(Reverb)_Reverb_HQ_By_FoxJoy.wav...
#
# 2025-08-28 14:41:00.492 | INFO | common_separator | Audio duration is 0.10 hours (344.00 seconds).
#
# 2025-08-28 14:41:00.492 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:41:00.945 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 14:41:00.946 | INFO | separator | Separation duration: 00:00:35
#
# 2025-08-28 14:41:00.946 | INFO | separator_music | Original vocal reverb removal successful!
#
# 2025-08-28 14:41:00.947 | INFO | separator_music | Music separation completed in 65.41 seconds
#
# 2025-08-28 14:41:01.774 | INFO | utils | Completed!
#
# 2025-08-28 14:46:25.816 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
# rmvpe.pt: 100% 181184272/181184272 [00:00<00:00, 239653106.14byte/s]
# hubert_base.pt: 100% 189507909/189507909 [00:00<00:00, 252090126.19byte/s]
#
# 2025-08-28 14:46:31.522 | INFO | convert | Convert Audio 'audios/Original_Vocals_No_Reverb.wav'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:29<00:00,  2.92s/a]
#
# 2025-08-28 14:47:00.732 | INFO | convert | File audios/Original_Vocals_No_Reverb.wav converted successfully in 29.21 seconds. audios/output.wav
#
# 2025-08-28 14:47:01.586 | INFO | utils | Voice conversion completed!
#
# 2025-08-28 14:49:56.796 | WARNING | utils | Please provide valid input!
#
# 2025-08-28 14:50:50.194 | INFO | utils | Starting music separation...
#
# 2025-08-28 14:50:52.128 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 14:50:52.128 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 14:50:52.129 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 14:50:52.130 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 14:50:52.130 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 14:50:52.130 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 14:50:52.131 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 14:50:52.131 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 14:50:52.131 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 14:50:52.131 | INFO | separator | Loading model Kim_Vocal_2.onnx...
# Kim_Vocal_2.onnx: 100% 66759214/66759214 [00:01<00:00, 58853702.79byte/s]
#
# 2025-08-28 14:50:56.792 | INFO | separator | Model loading duration: 00:00:04
#
# 2025-08-28 14:50:56.793 | INFO | separator | Starting separation process for audio file path: audios/MYTH  ROID - 追想轮回.flac
# 100%|████████████████████████████████████████████████████████████████| 14/14 [00:17<00:00,  1.26s/f]
# 100%|████████████████████████████████████████████████████████████████| 11/11 [00:05<00:00,  1.87f/s]
#
# 2025-08-28 14:51:22.109 | INFO | mdx_separator | Saving secondary stem Instrumental to MYTH  ROID - 追想轮回_(Instrumental)_Kim_Vocal_2.wav...
#
# 2025-08-28 14:51:22.111 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 14:51:22.111 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:51:22.295 | INFO | mdx_separator | Saving secondary stem Vocals to MYTH  ROID - 追想轮回_(Vocals)_Kim_Vocal_2.wav...
#
# 2025-08-28 14:51:22.297 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 14:51:22.297 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:51:22.631 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 14:51:22.632 | INFO | separator | Separation duration: 00:00:25
#
# 2025-08-28 14:51:22.632 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 14:51:22.633 | INFO | separator_music | Processing original vocal reverb removal...
#
# 2025-08-28 14:51:22.633 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 14:51:22.633 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 14:51:22.633 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 14:51:22.633 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 14:51:22.633 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 14:51:22.634 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 14:51:22.634 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 14:51:22.634 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 14:51:22.634 | INFO | separator | Loading model Reverb_HQ_By_FoxJoy.onnx...
#
# 2025-08-28 14:51:23.461 | INFO | separator | Model loading duration: 00:00:00
#
# 2025-08-28 14:51:23.461 | INFO | separator | Starting separation process for audio file path: audios/MYTH  ROID - 追想轮回/Original_Vocals.wav
# 100%|████████████████████████████████████████████████████████████████| 14/14 [00:17<00:00,  1.24s/f]
# 100%|████████████████████████████████████████████████████████████████| 11/11 [00:06<00:00,  1.82f/s]
#
# 2025-08-28 14:51:47.395 | INFO | mdx_separator | Saving secondary stem No Reverb to Original_Vocals_(No Reverb)_Reverb_HQ_By_FoxJoy.wav...
#
# 2025-08-28 14:51:47.397 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 14:51:47.397 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:51:47.571 | INFO | mdx_separator | Saving secondary stem Reverb to Original_Vocals_(Reverb)_Reverb_HQ_By_FoxJoy.wav...
#
# 2025-08-28 14:51:47.572 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 14:51:47.572 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 14:51:47.906 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 14:51:47.907 | INFO | separator | Separation duration: 00:00:24
#
# 2025-08-28 14:51:47.907 | INFO | separator_music | Original vocal reverb removal successful!
#
# 2025-08-28 14:51:47.907 | INFO | separator_music | Music separation completed in 55.78 seconds
#
# 2025-08-28 14:51:48.745 | INFO | utils | Completed!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 626, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2229, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1740, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2476, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 940, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/program/main/app/tabs/inference/inference.py", line 211, in <lambda>
#     input0.upload(fn=lambda audio_in: shutil.move(audio_in.name, os.path.join("audios")), inputs=[input0], outputs=[input_audio0])
#                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/shutil.py", line 845, in move
#     raise Error("Destination path '%s' already exists" % real_dst)
# shutil.Error: Destination path 'audios/Original_Vocals_No_Reverb.wav' already exists
#
# 2025-08-28 14:57:44.060 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 14:57:48.063 | INFO | convert | Convert Audio 'audios/Original_Vocals_No_Reverb.wav'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:20<00:00,  2.01s/a]
#
# 2025-08-28 14:58:08.197 | INFO | convert | File audios/Original_Vocals_No_Reverb.wav converted successfully in 20.13 seconds. audios/output.wav
#
# 2025-08-28 14:58:08.978 | INFO | utils | Voice conversion completed!
#
# 2025-08-28 15:04:20.779 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 15:04:23.916 | INFO | convert | Convert Audio 'audios/112 120.mp3'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:06<00:00,  1.56a/s]
#
# 2025-08-28 15:04:30.337 | INFO | convert | File audios/112 120.mp3 converted successfully in 6.42 seconds. audios/output.wav
#
# 2025-08-28 15:04:31.078 | INFO | utils | Voice conversion completed!
#
# 2025-08-28 15:05:40.585 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 15:05:43.666 | INFO | convert | Convert Audio 'audios/112 120.mp3'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:06<00:00,  1.53a/s]
#
# 2025-08-28 15:05:50.189 | INFO | convert | File audios/112 120.mp3 converted successfully in 6.52 seconds. audios/output.wav
#
# 2025-08-28 15:05:50.929 | INFO | utils | Voice conversion completed!
#
# 2025-08-28 15:11:42.492 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 15:11:45.670 | INFO | convert | Convert Audio 'audios/112 120.mp3'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:06<00:00,  1.49a/s]
#
# 2025-08-28 15:11:52.394 | INFO | convert | File audios/112 120.mp3 converted successfully in 6.72 seconds. audios/output.wav
#
# 2025-08-28 15:11:53.120 | INFO | utils | Voice conversion completed!
#
# 2025-08-28 15:13:17.502 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 15:13:21.350 | INFO | convert | Convert Audio 'audios/112 120.mp3'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:05<00:00,  1.75a/s]
#
# 2025-08-28 15:13:27.053 | INFO | convert | File audios/112 120.mp3 converted successfully in 5.70 seconds. audios/output.wav
#
# 2025-08-28 15:13:27.795 | INFO | utils | Voice conversion completed!
#
# 2025-08-28 15:16:03.798 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 15:16:06.876 | INFO | convert | Convert Audio 'audios/Original_Vocals_No_Reverb.mp3'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:05<00:00,  1.69a/s]
#
# 2025-08-28 15:16:12.781 | INFO | convert | File audios/Original_Vocals_No_Reverb.mp3 converted successfully in 5.90 seconds. audios/output.wav
#
# 2025-08-28 15:16:13.508 | INFO | utils | Voice conversion completed!
#
# 2025-08-28 15:21:39.103 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 15:21:42.204 | INFO | convert | Convert Audio 'audios/Original_Vocals_No_Reverb_1.mp3'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:05<00:00,  1.79a/s]
#
# 2025-08-28 15:21:47.798 | INFO | convert | File audios/Original_Vocals_No_Reverb_1.mp3 converted successfully in 5.59 seconds. audios/output.wav
#
# 2025-08-28 15:21:48.548 | INFO | utils | Voice conversion completed!
#
# 2025-08-28 15:22:28.900 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 15:22:31.975 | INFO | convert | Convert Audio 'audios/Original_Vocals_No_Reverb_1.mp3'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:06<00:00,  1.57a/s]
#
# 2025-08-28 15:22:38.329 | INFO | convert | File audios/Original_Vocals_No_Reverb_1.mp3 converted successfully in 6.35 seconds. audios/output.wav
#
# 2025-08-28 15:22:39.058 | INFO | utils | Voice conversion completed!
#
# 2025-08-28 15:29:30.912 | INFO | utils | Starting music separation...
#
# 2025-08-28 15:29:32.833 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 15:29:32.833 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 15:29:32.833 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 15:29:32.834 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 15:29:32.834 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 15:29:32.834 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 15:29:32.835 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 15:29:32.835 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 15:29:32.836 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 15:29:32.836 | INFO | separator | Loading model UVR-MDX-NET-Voc_FT.onnx...
# UVR-MDX-NET-Voc_FT.onnx: 100% 66762490/66762490 [00:01<00:00, 46967377.01byte/s]
#
# 2025-08-28 15:29:37.450 | INFO | separator | Model loading duration: 00:00:04
#
# 2025-08-28 15:29:37.450 | INFO | separator | Starting separation process for audio file path: audios/MYTH  ROID - 追想轮回.flac
# 100%|██████████████████████████████████████████████████████████████████| 7/7 [00:26<00:00,  3.79s/f]
# 100%|██████████████████████████████████████████████████████████████████| 6/6 [00:09<00:00,  1.55s/f]
#
# 2025-08-28 15:30:15.826 | INFO | mdx_separator | Saving secondary stem Instrumental to MYTH  ROID - 追想轮回_(Instrumental)_UVR-MDX-NET-Voc_FT.wav...
#
# 2025-08-28 15:30:15.829 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 15:30:15.829 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 15:30:16.078 | INFO | mdx_separator | Saving secondary stem Vocals to MYTH  ROID - 追想轮回_(Vocals)_UVR-MDX-NET-Voc_FT.wav...
#
# 2025-08-28 15:30:16.080 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 15:30:16.080 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 15:30:16.515 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 15:30:16.522 | INFO | separator | Separation duration: 00:00:39
#
# 2025-08-28 15:30:16.522 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 15:30:16.522 | INFO | separator_music | Processing original vocal reverb removal...
#
# 2025-08-28 15:30:16.522 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 15:30:16.522 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 15:30:16.522 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 15:30:16.522 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 15:30:16.522 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 15:30:16.523 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 15:30:16.524 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 15:30:16.524 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 15:30:16.524 | INFO | separator | Loading model Reverb_HQ_By_FoxJoy.onnx...
#
# 2025-08-28 15:30:17.264 | INFO | separator | Model loading duration: 00:00:00
#
# 2025-08-28 15:30:17.264 | INFO | separator | Starting separation process for audio file path: audios/MYTH  ROID - 追想轮回/Original_Vocals.wav
# 100%|██████████████████████████████████████████████████████████████████| 7/7 [00:28<00:00,  4.00s/f]
# 100%|██████████████████████████████████████████████████████████████████| 6/6 [00:09<00:00,  1.55s/f]
#
# 2025-08-28 15:30:55.557 | INFO | mdx_separator | Saving secondary stem No Reverb to Original_Vocals_(No Reverb)_Reverb_HQ_By_FoxJoy.wav...
#
# 2025-08-28 15:30:55.559 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 15:30:55.559 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 15:30:55.802 | INFO | mdx_separator | Saving secondary stem Reverb to Original_Vocals_(Reverb)_Reverb_HQ_By_FoxJoy.wav...
#
# 2025-08-28 15:30:55.803 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 15:30:55.803 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 15:30:56.246 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 15:30:56.247 | INFO | separator | Separation duration: 00:00:38
#
# 2025-08-28 15:30:56.247 | INFO | separator_music | Original vocal reverb removal successful!
#
# 2025-08-28 15:30:56.247 | INFO | separator_music | Music separation completed in 83.42 seconds
#
# 2025-08-28 15:30:57.086 | INFO | utils | Completed!
#
# 2025-08-28 15:35:23.679 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 15:35:26.835 | INFO | convert | Convert Audio 'audios/Original_Vocals_No_Reverb 1.wav'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:21<00:00,  2.11s/a]
#
# 2025-08-28 15:35:47.962 | INFO | convert | File audios/Original_Vocals_No_Reverb 1.wav converted successfully in 21.13 seconds. audios/output.wav
#
# 2025-08-28 15:35:48.733 | INFO | utils | Voice conversion completed!
#
# 2025-08-28 15:38:14.981 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 15:38:18.095 | INFO | convert | Convert Audio 'audios/Original_Vocals_No_Reverb 1.wav'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:20<00:00,  2.06s/a]
#
# 2025-08-28 15:38:38.702 | INFO | convert | File audios/Original_Vocals_No_Reverb 1.wav converted successfully in 20.61 seconds. audios/output.wav
#
# 2025-08-28 15:38:39.467 | INFO | utils | Voice conversion completed!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 626, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2229, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1740, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2476, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 940, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/program/main/app/app.py", line 97, in <lambda>
#     input.upload(fn=lambda audio_in: shutil.move(audio_in.name, os.path.join("audios")), inputs=[input], outputs=[input_audio])
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/shutil.py", line 845, in move
#     raise Error("Destination path '%s' already exists" % real_dst)
# shutil.Error: Destination path 'audios/MYTH  ROID - 追想轮回.flac' already exists
#
# 2025-08-28 15:40:17.027 | WARNING | utils | Please provide valid input!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 626, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2229, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1740, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2476, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 940, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/program/main/app/app.py", line 97, in <lambda>
#     input.upload(fn=lambda audio_in: shutil.move(audio_in.name, os.path.join("audios")), inputs=[input], outputs=[input_audio])
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/shutil.py", line 845, in move
#     raise Error("Destination path '%s' already exists" % real_dst)
# shutil.Error: Destination path 'audios/MYTH  ROID - 追想轮回.flac' already exists
#
# 2025-08-28 15:42:40.339 | WARNING | utils | Please provide valid input!
#
# 2025-08-28 15:43:40.026 | INFO | utils | Starting music separation...
#
# 2025-08-28 15:43:42.521 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 15:43:42.521 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 15:43:42.521 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 15:43:42.523 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 15:43:42.523 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 15:43:42.523 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 15:43:42.524 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 15:43:42.524 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 15:43:42.524 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 15:43:42.524 | INFO | separator | Loading model UVR-MDX-NET-Inst_HQ_5.onnx...
#
# 2025-08-28 15:43:45.277 | INFO | separator | Model loading duration: 00:00:02
#
# 2025-08-28 15:43:45.277 | INFO | separator | Starting separation process for audio file path: audios/MYTH  ROID - 追想轮回.flac
# 100%|██████████████████████████████████████████████████████████████████| 6/6 [00:20<00:00,  3.41s/f]
# 100%|██████████████████████████████████████████████████████████████████| 5/5 [00:06<00:00,  1.33s/f]
#
# 2025-08-28 15:44:14.783 | INFO | mdx_separator | Saving secondary stem Vocals to MYTH  ROID - 追想轮回_(Vocals)_UVR-MDX-NET-Inst_HQ_5.wav...
#
# 2025-08-28 15:44:14.785 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 15:44:14.785 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 15:44:14.963 | INFO | mdx_separator | Saving secondary stem Instrumental to MYTH  ROID - 追想轮回_(Instrumental)_UVR-MDX-NET-Inst_HQ_5.wav...
#
# 2025-08-28 15:44:14.965 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 15:44:14.965 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 15:44:15.282 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 15:44:15.283 | INFO | separator | Separation duration: 00:00:30
#
# 2025-08-28 15:44:15.283 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 15:44:15.283 | INFO | separator_music | Music separation completed in 32.76 seconds
#
# 2025-08-28 15:44:16.104 | INFO | utils | Completed!
#
# 2025-08-28 15:48:38.688 | INFO | utils | Starting music separation...
#
# 2025-08-28 15:48:40.532 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 15:48:40.532 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 15:48:40.532 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 15:48:40.534 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 15:48:40.534 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 15:48:40.534 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 15:48:40.535 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 15:48:40.535 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 15:48:40.535 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 15:48:40.535 | INFO | separator | Loading model UVR-MDX-NET-Inst_Main.onnx...
#
# 2025-08-28 15:48:43.088 | INFO | separator | Model loading duration: 00:00:02
#
# ...
#
# 2025-08-28 15:54:20.268 | WARNING | separator_music | Original vocal not found!
#
# 2025-08-28 15:54:21.096 | INFO | utils | Completed!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 626, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2229, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 1740, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 2476, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/anyio/_backends/_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/utils.py", line 940, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/program/main/app/app.py", line 97, in <lambda>
#     input.upload(fn=lambda audio_in: shutil.move(audio_in.name, os.path.join("audios")), inputs=[input], outputs=[input_audio])
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/shutil.py", line 845, in move
#     raise Error("Destination path '%s' already exists" % real_dst)
# shutil.Error: Destination path 'audios/MYTH  ROID - 追想轮回.flac' already exists
#
# 2025-08-28 15:58:18.804 | INFO | utils | Starting music separation...
#
# 2025-08-28 15:58:20.625 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 15:58:20.625 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 15:58:20.626 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 15:58:20.627 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 15:58:20.627 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 15:58:20.627 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 15:58:20.628 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 15:58:20.628 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 15:58:20.628 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 15:58:20.628 | INFO | separator | Loading model UVR-MDX-NET-Inst_3.onnx...
# UVR-MDX-NET-Inst_3.onnx: 100% 66759214/66759214 [00:01<00:00, 58256905.69byte/s]
#
# 2025-08-28 15:58:24.402 | INFO | separator | Model loading duration: 00:00:03
#
# 2025-08-28 15:58:24.402 | INFO | separator | Starting separation process for audio file path: audios/MYTH  ROID - 追想轮回.flac
# 100%|████████████████████████████████████████████████████████████████| 54/54 [00:30<00:00,  1.76f/s]
# 100%|████████████████████████████████████████████████████████████████| 41/41 [00:04<00:00,  8.94f/s]
#
# 2025-08-28 15:59:01.425 | INFO | mdx_separator | Saving secondary stem Vocals to MYTH  ROID - 追想轮回_(Vocals)_UVR-MDX-NET-Inst_3.wav...
#
# 2025-08-28 15:59:01.427 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 15:59:01.427 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 15:59:01.610 | INFO | mdx_separator | Saving secondary stem Instrumental to MYTH  ROID - 追想轮回_(Instrumental)_UVR-MDX-NET-Inst_3.wav...
#
# 2025-08-28 15:59:01.613 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 15:59:01.613 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 15:59:01.944 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 15:59:01.945 | INFO | separator | Separation duration: 00:00:37
#
# 2025-08-28 15:59:01.967 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 15:59:01.967 | INFO | separator_music | Processing original vocal reverb removal...
#
# 2025-08-28 15:59:01.968 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 15:59:01.968 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 15:59:01.968 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 15:59:01.968 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 15:59:01.968 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 15:59:01.969 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 15:59:01.969 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 15:59:01.969 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 15:59:01.970 | INFO | separator | Loading model Reverb_HQ_By_FoxJoy.onnx...
#
# 2025-08-28 15:59:02.844 | INFO | separator | Model loading duration: 00:00:00
#
# 2025-08-28 15:59:02.844 | INFO | separator | Starting separation process for audio file path: audios/MYTH  ROID - 追想轮回/Original_Vocals.wav
# 100%|████████████████████████████████████████████████████████████████| 53/53 [00:28<00:00,  1.84f/s]
# 100%|████████████████████████████████████████████████████████████████| 40/40 [00:04<00:00,  9.16f/s]
#
# 2025-08-28 15:59:36.615 | INFO | mdx_separator | Saving secondary stem No Reverb to Original_Vocals_(No Reverb)_Reverb_HQ_By_FoxJoy.wav...
#
# 2025-08-28 15:59:36.616 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 15:59:36.617 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 15:59:36.793 | INFO | mdx_separator | Saving secondary stem Reverb to Original_Vocals_(Reverb)_Reverb_HQ_By_FoxJoy.wav...
#
# 2025-08-28 15:59:36.795 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 15:59:36.795 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 15:59:37.118 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 15:59:37.118 | INFO | separator | Separation duration: 00:00:34
#
# 2025-08-28 15:59:37.119 | INFO | separator_music | Original vocal reverb removal successful!
#
# 2025-08-28 15:59:37.119 | INFO | separator_music | Music separation completed in 76.50 seconds
#
# 2025-08-28 15:59:37.962 | INFO | utils | Completed!
#
# 2025-08-28 16:01:40.076 | INFO | utils | Starting music separation...
#
# 2025-08-28 16:01:42.504 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 16:01:42.504 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 16:01:42.504 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 16:01:42.506 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 16:01:42.506 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 16:01:42.506 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 16:01:42.507 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 16:01:42.508 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 16:01:42.508 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 16:01:42.508 | INFO | separator | Loading model UVR_MDXNET_Main.onnx...
# UVR_MDXNET_Main.onnx: 100% 66759214/66759214 [00:01<00:00, 35970916.12byte/s]
#
# 2025-08-28 16:01:47.804 | INFO | separator | Model loading duration: 00:00:05
#
# 2025-08-28 16:01:47.804 | INFO | separator | Starting separation process for audio file path: audios/MYTH  ROID - 追想轮回.flac
# 100%|██████████████████████████████████████████████████████████████████| 6/6 [00:39<00:00,  6.64s/f]
# 100%|██████████████████████████████████████████████████████████████████| 5/5 [00:08<00:00,  1.63s/f]
#
# 2025-08-28 16:02:38.003 | INFO | mdx_separator | Saving secondary stem Instrumental to MYTH  ROID - 追想轮回_(Instrumental)_UVR_MDXNET_Main.wav...
#
# 2025-08-28 16:02:38.006 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 16:02:38.006 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 16:02:38.180 | INFO | mdx_separator | Saving secondary stem Vocals to MYTH  ROID - 追想轮回_(Vocals)_UVR_MDXNET_Main.wav...
#
# 2025-08-28 16:02:38.182 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 16:02:38.182 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 16:02:38.508 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 16:02:38.516 | INFO | separator | Separation duration: 00:00:50
#
# 2025-08-28 16:02:38.517 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 16:02:38.517 | INFO | separator_music | Music separation completed in 56.03 seconds
#
# 2025-08-28 16:02:39.375 | INFO | utils | Completed!
#
# 2025-08-28 16:03:57.069 | INFO | utils | Starting music separation...
#
# 2025-08-28 16:03:58.897 | INFO | separator_music | Processing music separation...
#
# 2025-08-28 16:03:58.897 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 16:03:58.897 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 16:03:58.898 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 16:03:58.898 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 16:03:58.899 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 16:03:58.899 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 16:03:58.900 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 16:03:58.900 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 16:03:58.900 | INFO | separator | Loading model UVR_MDXNET_Main.onnx...
#
# 2025-08-28 16:04:01.669 | INFO | separator | Model loading duration: 00:00:02
#
# 2025-08-28 16:04:01.669 | INFO | separator | Starting separation process for audio file path: audios/MYTH  ROID - 追想轮回.flac
# 100%|██████████████████████████████████████████████████████████████████| 6/6 [00:23<00:00,  3.87s/f]
# 100%|██████████████████████████████████████████████████████████████████| 5/5 [00:07<00:00,  1.56s/f]
#
# 2025-08-28 16:04:34.484 | INFO | mdx_separator | Saving secondary stem Instrumental to MYTH  ROID - 追想轮回_(Instrumental)_UVR_MDXNET_Main.wav...
#
# 2025-08-28 16:04:34.486 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 16:04:34.487 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 16:04:34.672 | INFO | mdx_separator | Saving secondary stem Vocals to MYTH  ROID - 追想轮回_(Vocals)_UVR_MDXNET_Main.wav...
#
# 2025-08-28 16:04:34.674 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 16:04:34.674 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 16:04:34.979 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 16:04:34.980 | INFO | separator | Separation duration: 00:00:33
#
# 2025-08-28 16:04:34.980 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 16:04:34.980 | INFO | separator_music | Processing backup vocal separation...
#
# 2025-08-28 16:04:34.980 | INFO | separator | Initializing with output path: audios/MYTH  ROID - 追想轮回, output format: wav
#
# 2025-08-28 16:04:34.980 | INFO | separator | Operating System: Linux #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
#
# 2025-08-28 16:04:34.981 | INFO | separator | System: uname_result(system='Linux', node='99cf471e10a0', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') Name: 99cf471e10a0 Release: 6.1.123+ Machine: x86_64 Processor: x86_64
#
# 2025-08-28 16:04:34.981 | INFO | separator | Version python: 3.12.11
#
# 2025-08-28 16:04:34.981 | INFO | separator | Version pytorch: 2.8.0+cu126
#
# 2025-08-28 16:04:34.982 | INFO | separator | ONNX Runtime package GPU installed with version: 1.22.0
#
# 2025-08-28 16:04:34.982 | INFO | separator | CUDA available in Torch, setting Torch device to CUDA
#
# 2025-08-28 16:04:34.982 | INFO | separator | ONNXruntime available CUDAExecutionProvider, enabling acceleration
#
# 2025-08-28 16:04:34.982 | INFO | separator | Loading model UVR_MDXNET_KARA.onnx...
# UVR_MDXNET_KARA.onnx: 100% 29704436/29704436 [00:00<00:00, 38222085.08byte/s]
#
# 2025-08-28 16:04:36.662 | INFO | separator | Model loading duration: 00:00:01
#
# 2025-08-28 16:04:36.662 | INFO | separator | Starting separation process for audio file path: audios/MYTH  ROID - 追想轮回/Original_Vocals.wav
# 100%|██████████████████████████████████████████████████████████████████| 6/6 [00:13<00:00,  2.17s/f]
# 100%|██████████████████████████████████████████████████████████████████| 5/5 [00:07<00:00,  1.50s/f]
#
# 2025-08-28 16:04:57.864 | INFO | mdx_separator | Saving secondary stem Instrumental to Original_Vocals_(Instrumental)_UVR_MDXNET_KARA.wav...
#
# 2025-08-28 16:04:57.865 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 16:04:57.865 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 16:04:58.042 | INFO | mdx_separator | Saving secondary stem Vocals to Original_Vocals_(Vocals)_UVR_MDXNET_KARA.wav...
#
# 2025-08-28 16:04:58.043 | INFO | common_separator | Audio duration is 0.06 hours (230.16 seconds).
#
# 2025-08-28 16:04:58.043 | INFO | common_separator | Using pydub to write.
#
# 2025-08-28 16:04:58.369 | INFO | common_separator | Deleting path, source, and root of input audio file...
#
# 2025-08-28 16:04:58.370 | INFO | separator | Separation duration: 00:00:21
#
# 2025-08-28 16:04:58.370 | INFO | separator_music | Backup vocal separation successful!
#
# 2025-08-28 16:04:58.370 | INFO | separator_music | Music separation completed in 59.48 seconds
#
# 2025-08-28 16:04:59.236 | INFO | utils | Completed!
#
# 2025-08-28 16:10:07.654 | INFO | utils | Converting voice...
# /content/program/main/inference/convert.py:284: SyntaxWarning: invalid escape sequence '\['
#   methods_str = re.search("hybrid\[(.+)\]", methods_str)
#
# 2025-08-28 16:10:11.027 | INFO | convert | Convert Audio 'audios/Main_Vocals.wav'...
# Convert Audio: 100%|█████████████████████████████████████████████████| 10/10 [00:20<00:00,  2.03s/a]
#
# 2025-08-28 16:10:31.330 | INFO | convert | File audios/Main_Vocals.wav converted successfully in 20.30 seconds. audios/output.wav
#
# 2025-08-28 16:10:32.088 | INFO | utils | Voice conversion completed!

# %% [markdown]
# ## Extra

# %%
#@title **Mount Google Drive**
#@markdown Mount Google Drive to store or access files for Ultimate RVC Maker.

from google.colab import drive

try:
    drive.mount("/content/drive", force_remount=False)
    print("✅ Google Drive mounted successfully.")
except Exception as e:
    print(f"⚠️ Failed to mount Google Drive: {e}")

#@markdown **Note:** Ensure you have sufficient space in Google Drive for backups.

# %%
#@title **Toggle Auto Backup**
#@markdown Enable or disable automatic backups to Google Drive. Backups save logs from `/content/program/assets/logs` to `/content/drive/MyDrive/RVCBackup`.

import os
import shutil
import time
import threading

LOGS_FOLDER = "/content/program/assets/logs"
GOOGLE_DRIVE_PATH = "/content/drive/MyDrive/RVCBackup"

if "autobackups" not in globals():
    autobackups = False

#@markdown **Backup Cooldown**: Time (in seconds) between checks when files are up to date.
cooldown = 15 #@param {type:"slider", min:0, max:100, step:1}

def backup_files():
    if not os.path.exists(GOOGLE_DRIVE_PATH):
        print(f"⚠️ Google Drive not mounted at {GOOGLE_DRIVE_PATH}. Please run the 'Mount Google Drive' cell first.")
        return

    print("Starting backup loop...")
    last_backup_timestamps_path = os.path.join(LOGS_FOLDER, "last_backup_timestamps.txt")
    fully_updated = False

    while True:
        try:
            updated_files, deleted_files, new_files = 0, 0, 0
            last_backup_timestamps = {}

            # Load previous timestamps
            try:
                with open(last_backup_timestamps_path, "r") as f:
                    last_backup_timestamps = {k: float(v) for k, v in (line.strip().split(":", 1) for line in f)}
            except FileNotFoundError:
                pass

            # Backup new or updated files
            for root, dirs, files in os.walk(LOGS_FOLDER):
                dirs[:] = [d for d in dirs if d not in ("zips", "mute")]
                for filename in files:
                    if filename != "last_backup_timestamps.txt":
                        filepath = os.path.join(root, filename)
                        if os.path.isfile(filepath):
                            backup_filepath = os.path.join(GOOGLE_DRIVE_PATH, os.path.relpath(filepath, LOGS_FOLDER))
                            os.makedirs(os.path.dirname(backup_filepath), exist_ok=True)
                            current_timestamp = os.path.getmtime(filepath)
                            last_backup_timestamp = last_backup_timestamps.get(filepath)
                            if last_backup_timestamp is None or last_backup_timestamp < current_timestamp:
                                shutil.copy2(filepath, backup_filepath)
                                last_backup_timestamps[filepath] = current_timestamp
                                if last_backup_timestamp is None:
                                    new_files += 1
                                else:
                                    updated_files += 1

            # Remove deleted files from backup
            for filepath in list(last_backup_timestamps.keys()):
                if not os.path.exists(filepath):
                    backup_filepath = os.path.join(GOOGLE_DRIVE_PATH, os.path.relpath(filepath, LOGS_FOLDER))
                    if os.path.exists(backup_filepath):
                        os.remove(backup_filepath)
                        deleted_files += 1
                    del last_backup_timestamps[filepath]

            # Log backup status
            if new_files > 0 or updated_files > 0 or deleted_files > 0:
                print(f"Backup Complete: {new_files} new, {updated_files} updated, {deleted_files} deleted.")
                fully_updated = False
            elif not fully_updated:
                print("Files are up to date.")
                fully_updated = True

            # Save timestamps
            with open(last_backup_timestamps_path, "w") as f:
                for filepath, timestamp in last_backup_timestamps.items():
                    f.write(f"{filepath}:{timestamp}\n")

            time.sleep(cooldown if fully_updated else 0.1)

        except Exception as error:
            print(f"Error during backup: {error}")
            time.sleep(5)

# Toggle autobackup
if autobackups:
    autobackups = False
    print("✅ Autobackup disabled.")
else:
    autobackups = True
    print("✅ Autobackup enabled.")
    threading.Thread(target=backup_files, daemon=True).start()

#@markdown **Note:** Ensure Google Drive is mounted before enabling backups. The backup runs in the background and checks for changes every 0.1s (or `cooldown` seconds when up to date).

# %%
#@title **Upload Model to Hugging Face**
#@markdown Upload your trained model and index file to a Hugging Face repository.

import huggingface_hub
import zipfile
import os

#@markdown **Repository ID**: Format as `username/repo_name`.
repo_hf = "NeoPy/TTS-G" #@param {type:"string"}

#@markdown **Model Path**: Path to the `.pth` model file.
pth = "/content/program/assets/weights/TTS_100e_500s.pth" #@param {type:"string"}

#@markdown **Index Path**: Path to the `.index` file.
index = "/content/program/assets/logs/TTS/added_IVF59_Flat_nprobe_1_TTS_v2.index" #@param {type:"string"}

#@markdown **Hugging Face Token**: Get it from [Hugging Face settings](https://huggingface.co/settings/tokens).
token = "hf_" #@param {type:"string"}

def upload_model(repo, pth, index, token):
    try:
        # Validate inputs
        if not repo or '/' not in repo:
            return "❌ Invalid repository ID. Use format: username/repo_name"
        if not token.startswith("hf_"):
            return "❌ Invalid Hugging Face token. It should start with 'hf_'"
        if not os.path.exists(pth):
            return f"❌ Model file not found at {pth}"
        if not os.path.exists(index):
            return f"❌ Index file not found at {index}"

        # Create README
        repo_name = repo.split('/')[-1]
        readme = f"""
# {repo_name}
This model was trained and uploaded using [Ultimate RVC Maker](https://github.com/unchCrew/RVC-MAKER) by [TheNeoDev](https://github.com/TheNeodev).
        """

        # Create zip file
        zip_path = f"{repo_name}.zip"
        with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
            zipf.write(pth, os.path.basename(pth))
            zipf.write(index, os.path.basename(index))
            zipf.writestr('README.md', readme)

        # Upload to Hugging Face
        api = huggingface_hub.HfApi()
        api.create_repo(repo_id=repo, token=token, exist_ok=True)
        api.upload_file(
            path_or_fileobj=zip_path,
            path_in_repo=f"{repo_name}.zip",
            repo_id=repo,
            token=token
        )

        # Clean up
        os.remove(zip_path)
        return "✅ Model uploaded successfully to Hugging Face!"

    except Exception as e:
        return f"❌ Error uploading model: {e}"

# Execute upload
print(upload_model(repo_hf, pth, index, token))

#@markdown **Note:** Ensure the model and index files exist at the specified paths. The upload creates a zip file containing both files and a README.

# %%
#@title **Clean Up Temporary Files**
#@markdown Remove temporary files to free up space in the Colab environment.

import os
import shutil

def clean_temp_files():
    temp_dirs = ['/content/program', '/content/url.txt']
    freed_space = 0
    for path in temp_dirs:
        try:
            if os.path.isfile(path):
                size = os.path.getsize(path) / (1024 * 1024)  # Size in MB
                os.remove(path)
                freed_space += size
                print(f"Removed file: {path}")
            elif os.path.isdir(path):
                size = sum(os.path.getsize(os.path.join(root, f)) for root, _, files in os.walk(path) for f in files) / (1024 * 1024)
                shutil.rmtree(path, ignore_errors=True)
                freed_space += size
                print(f"Removed directory: {path}")
        except Exception as e:
            print(f"Error removing {path}: {e}")
    return f"✅ Cleaned up temporary files. Freed approximately {freed_space:.2f} MB."

print(clean_temp_files())

#@markdown **Warning:** This will delete the `/content/program` directory and other temporary files. Ensure you have backed up important data.
